# %%
import pandas as pd

df = pd.read_excel("data/2019 RPD.xlsx")

df
# Out:
#       IRB file no Date Referred Decision Date Date Decision Mailed  \
# 0       MA8-00400    2008-01-11    2019-04-11           2019-04-30
# 1       MB0-00633    2010-02-03    2019-01-21           2019-01-29
# 2       MB0-00637    2010-02-03    2019-01-21           2019-01-29
# 3       MB0-02611    2010-05-06    2019-01-03           2019-01-03
# 4       MB0-06849    2010-11-17    2019-01-14           2019-01-14
# ...           ...           ...           ...                  ...
# 23197   VB9-09267    2019-11-26    2019-11-27           2019-11-27
# 23198   VB9-09577    2019-12-05    2019-12-06           2019-12-06
# 23199   VB9-09982    2019-12-17    2019-12-30           2019-12-30
# 23200   VB9-09995    2019-12-17    2019-12-20           2019-12-20
# 23201   VB9-10227    2019-12-27    2019-12-30           2019-12-30
#
#       Explanation  Language of Record Minister Counsel Participation Type   \
# 0         Positive                  F                                  NaN
# ...
